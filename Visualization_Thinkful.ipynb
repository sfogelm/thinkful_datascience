# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
yelp = pd.read_csv('/Users/spencerfogelman/Downloads/yelp_business.csv')

# %%
yelp
# Out:
#                    business_id  \
# 0       FYWN1wneV18bWNgQjJ2GNg
# 1       He-G7vWjzVUysIKrfNbPUQ
# 2       KQPW8lFf1y5BT2MxiSZ3QA
# 3       8DShNS-LuFqpEWIp0HxijA
# 4       PfOCPjBrlQAnz__NXj9h_w
# 5       o9eMRCWt5PkpLDE0gOPtcQ
# 6       kCoE3jvEtg6UVz5SOD3GVw
# 7       OD2hnuuTJI9uotcKycxg1A
# 8       EsMcGiZaQuG1OOvL9iUFug
# 9       TGWhGNusxyMaA4kQVBNeew
# 10      XOSRcvtaKc_Q5H1SAzN20A
# 11      Y0eMNa5C-YU1RQOZf9XvVA
# 12      xcgFnd-MwkZeO5G2HQ0gAQ
# 13      NmZtoE3v8RdSJEczYbMT9g
# 14      fNMVV_ZX7CJSDWQGdOM8Nw
# 15      l09JfMeQ6ynYs5MCJtrcmQ
# 16      IQSlT5jGE6CCDhSG0zG3xg
# 17      b2I2DXtZVnpUMCXp1JON7A
# 18      0FMKDOU8TJT1x87OKYGDTg
# 19      Gu-xs3NIQTj3Mj2xYoN2aw
# 20      lHYiCS-y8AFjUitv6MGpxg
# 21      94KziT6DQ9XlBET3WzIv_w
# 22      7YIy1tXOor9VCwvaSjuBHg
# 23      PMH4oUa-bWELKogdtkWewg
# 24      VSGcuYDV3q-AAZ9ZPq4fBQ
# 25      1K4qrnfyzKzGgJPBEcJaNQ
# 26      VBHEsoXQb2AQ76J9l8h1uQ
# 27      AtdXq_gu9NTE5rx4ct_dGg
# 28      Dj0S-Oe4ytRJzMGUPgYUkw
# ...

# %%
plt.scatter(yelp['review_count'], yelp['stars'])
plt.show()
#Higher reviews has a positive correlation with stars. It is possible that the fact there are only 5 stars corresponding to 
#few reviews shows that people are trying to boost their product's desirability.

# %%
plt.boxplot(yelp['review_count'])
plt.show()
#There are too many outliers to get a good plot of the data without excluding data points.

# %%
plt.imshow(yelp.corr())
plt.matshow(yelp.corr())
plt.show()

# %%
print(yelp.corr())
# Out:
#               latitude  longitude     stars  review_count   is_open
# latitude      1.000000   0.839805 -0.053424     -0.074705 -0.006975
# longitude     0.839805   1.000000 -0.034137     -0.095415  0.008143
# stars        -0.053424  -0.034137  1.000000      0.030115  0.051798
# review_count -0.074705  -0.095415  0.030115      1.000000  0.035367
# is_open      -0.006975   0.008143  0.051798      0.035367  1.000000

# %%
plt.boxplot(yelp['latitude'])
plt.show()
# Out:
# /Users/spencerfogelman/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)

# %%
yelp['latitude']
# Out:
# 0         33.330690
# 1         40.291685
# 2         33.524903
# 3         33.383147
# 4         41.119535
# 5         48.727200
# 6         36.207430
# 7         36.197484
# 8         40.615102
# 9         36.055825
# 10        40.241548
# 11        33.271720
# 12        43.875177
# 13        40.401488
# 14        35.221647
# 15        43.711399
# 16        33.608654
# 17        43.185080
# 18        33.463629
# 19        43.867565
# 20        43.639863
# 21        33.380133
# 22        33.435463
# 23        43.592753
# 24        43.682867
# 25        43.669256
# 26        36.085051
# 27        43.656729
# 28        41.343078
# 29        35.047287
#             ...
# 174537    55.975580
# 174538    36.275588
# 174539    36.134355
# 174540    33.318047
# 174541    40.436981
# 174542    33.360239
# 174543    43.666034
# 174544    43.682054
# 174545    36.173589
# 174546    36.055130
# 174547    33.416962
# 174548    48.898590
# 174549    55.947855
# 174550    40.544559
# ...

# %%
yelp_group = yelp.groupby(['state']).mean().reset_index()
print(yelp_group)
# Out:
#    state   latitude   longitude     stars  review_count   is_open
# 0     01  59.432424   10.665623  3.700000      4.000000  1.000000
# 1      3  48.366900   16.382700  5.000000      4.000000  1.000000
# 2     30  44.126411    4.080825  3.000000      3.000000  1.000000
# 3      6  47.383869   13.774896  3.666667      3.333333  1.000000
# 4     AB  43.655199  -79.399961  5.000000      3.000000  1.000000
# 5    ABE  52.523772   -2.117878  4.000000      4.000000  1.000000
# 6     AK  33.276820 -111.790970  2.500000     22.000000  1.000000
# 7     AL  36.262458 -115.182004  5.000000     10.000000  1.000000
# 8     AR  33.448039 -111.771741  3.250000     15.000000  1.000000
# 9     AZ  33.493698 -111.988949  3.728722     31.173498  0.843548
# 10     B -34.418034  -58.572552  2.500000      6.000000  1.000000
# 11    BW  48.776037    9.171706  3.806126     11.352790  0.880693
# 12    BY  48.893544   10.844642  4.125000      3.750000  0.750000
# ...

# %%
yelp2 = yelp[yelp['state'].str.len() == 2]
yelp_group = yelp2.groupby(['state']).mean().reset_index()
print(yelp_group)
# Out:
#    state   latitude   longitude     stars  review_count   is_open
# 0     01  59.432424   10.665623  3.700000      4.000000  1.000000
# 1     30  44.126411    4.080825  3.000000      3.000000  1.000000
# 2     AB  43.655199  -79.399961  5.000000      3.000000  1.000000
# 3     AK  33.276820 -111.790970  2.500000     22.000000  1.000000
# 4     AL  36.262458 -115.182004  5.000000     10.000000  1.000000
# 5     AR  33.448039 -111.771741  3.250000     15.000000  1.000000
# 6     AZ  33.493698 -111.988949  3.728722     31.173498  0.843548
# 7     BW  48.776037    9.171706  3.806126     11.352790  0.880693
# 8     BY  48.893544   10.844642  4.125000      3.750000  0.750000
# 9     CA  37.039091  -91.583427  4.300000      6.400000  0.800000
# 10    CO  51.864294   -8.283347  3.750000      3.000000  1.000000
# 11    CS  39.967496   -0.263850  4.500000      3.000000  1.000000
# 12    DE  52.521870    7.317610  4.000000      5.000000  1.000000
# ...
